# %%
#importando a base de dados
import pandas as pd

# leitura da tabela e correção dos erros de acento e separador para melhor visualização
tabela = pd.read_csv("reclamacoes_contexto.csv", encoding="utf-8", sep=";")

#visualizando a base de dados 
display(tabela)
print(tabela.columns)
# Out:
# C:\Users\fabik\AppData\Local\Temp\ipykernel_11560\1276654185.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela = pd.read_csv("reclamacoes_contexto.csv", encoding="utf-8", sep=";")
#          DataExtracao  SOLICITAÇÕES   Ano  Mês   AnoMês  UF      Cidade  \
# 0          2018-04-23             1  2015    1  2015-01  DF    Brasília
# 1          2018-04-23             1  2015    1  2015-01  AC  Rio Branco
# 2          2018-04-23             1  2015    1  2015-01  AL      Maceió
# 3          2018-04-23             1  2015    1  2015-01  AM      Manaus
# 4          2018-04-23             1  2015    1  2015-01  AM      Manaus
# ...               ...           ...   ...  ...      ...  ..         ...
# 21854058   2024-01-10             1  2023   12  2023-12  SP    Sorocaba
# 21854059   2024-01-10             1  2023   12  2023-12  SP    Sorocaba
# 21854060   2024-01-10             1  2023   12  2023-12  SP     Taubaté
# 21854061   2024-01-10             1  2023   12  2023-12  TO      Palmas
# 21854062   2024-01-10             1  2023   12  2023-12  TO      Palmas
#
#          CO_MUNICIPIO  CanalEntrada       Condição       TipoAtendimento  \
# 0             5300108           SIC  Reencaminhada  Pedido de Informação
# 1             1200401  Fale Conosco           Nova            Reclamação
# 2             2704302  Fale Conosco           Nova            Reclamação
# 3             1302603  Fale Conosco  Reencaminhada            Reclamação
# 4             1302603  Fale Conosco           Nova            Reclamação
# ...               ...           ...            ...                   ...
# 21854058      3552205    Mobile App           Nova            Reclamação
# 21854059      3552205    Mobile App           Nova            Reclamação
# 21854060      3554102   Usuário WEB           Nova            Reclamação
# 21854061      1721000   Usuário WEB           Nova            Reclamação
# 21854062      1721000   Usuário WEB       Reaberta            Reclamação
#
#           Serviço   Marca                                            Assunto  \
# 0          Outros  Outros                                      NÃO APLICÁVEL
# 1            STFC      OI                Bloqueio ou Suspensão e Desbloqueio
# 2         SMP_Pós    VIVO  Qualidade e Funcionamento do Serviço ou Equipa...
# 3         SMP_Pré    VIVO                                   Crédito Pré-pago
# 4            STFC      OI  Qualidade e Funcionamento do Serviço ou Equipa...
# ...           ...     ...                                                ...
# 21854058  SMP_Pós   CLARO                 Bloqueio, desbloqueio ou Suspensão
# 21854059  SMP_Pré    VIVO                 Bloqueio, desbloqueio ou Suspensão
# 21854060  SMP_Pós    VIVO                                       Cancelamento
# 21854061  SMP_Pós   CLARO                                       Cancelamento
# 21854062  SMP_Pós   CLARO                 Bloqueio, desbloqueio ou Suspensão
#
#                                                    Problema     Linha
# 0                                                       SIC         1
# 1                            Bloqueio ou suspensão indevido         2
# 2                Lentidão ou velocidade reduzida de conexão         3
# 3              Crédito pré-pago cobrado de maneira indevida         4
# 4                                    Interrupção do serviço         5
# ...                                                     ...       ...
# 21854058                     Bloqueio ou suspensão indevido  21854059
# 21854059                     Bloqueio ou suspensão indevido  21854060
# 21854060  Não consegue registrar o pedido de cancelament...  21854061
# 21854061            Cancelamento indevido ou não solicitado  21854062
# 21854062  Ausência de notificação prévia do consumidor s...  21854063
#
# [21854063 rows x 16 columns]
# Index(['DataExtracao', 'SOLICITAÇÕES', 'Ano', 'Mês', 'AnoMês', 'UF', 'Cidade',
#        'CO_MUNICIPIO', 'CanalEntrada', 'Condição', 'TipoAtendimento',
#        'Serviço', 'Marca', 'Assunto', 'Problema', 'Linha'],
#       dtype='object')

# %%
#identificando os possíveis tratamentos necessários na tabela 
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21854063 entries, 0 to 21854062
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   DataExtracao     object
#  1   SOLICITAÇÕES     int64
#  2   Ano              int64
#  3   Mês              int64
#  4   AnoMês           object
#  5   UF               object
#  6   Cidade           object
#  7   CO_MUNICIPIO     object
#  8   CanalEntrada     object
#  9   Condição         object
#  10  TipoAtendimento  object
#  11  Serviço          object
#  12  Marca            object
#  13  Assunto          object
#  14  Problema         object
#  15  Linha            int64
# dtypes: int64(4), object(12)
# memory usage: 2.6+ GB
# None

# %%
#identificando valores nulos nas colunas
print(tabela.isna().sum())
# Out:
# DataExtracao           0
# SOLICITAÇÕES           0
# Ano                    0
# Mês                    0
# AnoMês                 0
# UF                     4
# Cidade             48299
# CO_MUNICIPIO           0
# CanalEntrada           0
# Condição               0
# TipoAtendimento        0
# Serviço                3
# Marca                  3
# Assunto                0
# Problema               0
# Linha                  0
# dtype: int64
